# %% [markdown]
# # AAPL stock movements

# %% [markdown]
# The purpose is to create a model that will predict up and down movements of one of the OHLC(Open,High,Low,Close) metrics - Close price. It displays the price of the stock at the end of the trading day. All the data will be drawn from Yahoo Finance.
# We'll use the following approach:
# - We'll create a model based on regression and we'll try to predict the Close value for the subsequent days. Note that we're not trying to predict the movements but the exact value of the target variable. Only after we already have the predictions we can transform them into up-down movements
# - We'll also use Exponential smoothing to reduce the complexity of the model and allow it not to overfit all the up and down movements.

# %% [markdown]
# ## Regression approach

# %% [markdown]
# This variant seems prospective because we'll be able to use Long short-term memory(LSTM) recurrent neural networks, which have a quite good performance when it comes to time series with no definite periods

# %% [markdown]
# #### Importing the neccessary libraries

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame as D
from pandas import Series as S
import matplotlib.pyplot as plt
from pandas_datareader import data as d #Will be used to read the data from yahoo finance
from datetime import date

# %% [markdown]
# #### Reading and visualizing the data

# %% [markdown]
# Start date here is 2017 because even well-optimized model can't catch the concept of the movements in the long period of time, because the stock prices now daily change far more drastically than 10 years ago forinstance

# %%
data = d.DataReader("AAPL", 
                    start='2017-01-01',
                    end=date.today(),
                    data_source='yahoo')
comparing_data = d.DataReader("AAPL", 
                            start='2000-04-30',
                            end=date.today(),
                            data_source='yahoo')

# %%
data.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2017-01-03  29.082500  28.690001  28.950001  29.037500  115127600.0  27.413372
# 2017-01-04  29.127501  28.937500  28.962500  29.004999   84472400.0  27.382690
# 2017-01-05  29.215000  28.952499  28.980000  29.152500   88774400.0  27.521944
# 2017-01-06  29.540001  29.117500  29.195000  29.477501  127007600.0  27.828764
# 2017-01-09  29.857500  29.485001  29.487499  29.747499  134247600.0  28.083660

# %%
figure, axes = plt.subplots(nrows=2, ncols=1,figsize=(20,10))
plt.subplots_adjust(hspace=0.3)
axes[0].plot(data.Close)
axes[0].set_title('Close Prices 2017-2021',fontsize=15,pad=10)
axes[1].plot(comparing_data.Close)
axes[1].set_title('Close Prices 2000-2021',fontsize=15,pad=10)
# Out:
# Text(0.5, 1.0, 'Close Prices 2000-2021')

# %% [markdown]
# #### Normalization

# %% [markdown]
# We'll use a technique which normalizes the data gradually by distinct intervals. The purpose is to set higher values to early stages of our data and retain their importance.

# %% [markdown]
# But first we need to split the time series into train and test sets

# %%
from sklearn.model_selection import train_test_split
test_size = 0.1
train_data,test_data = train_test_split(data.Close.values,random_state=42,test_size = test_size,shuffle=False)

# %%
#Function which normalizes the time series gradually
def grad_norm(train_data,test_data):
    global shape
    from sklearn.preprocessing import MinMaxScaler
    scaler = MinMaxScaler(copy=False)
    shape = train_data.shape[0]
    train_data = train_data.reshape(-1,1)
    step = int(round(shape/5,-1)) #The step of gradual normalization
    for i in range(0,4*step,step):
        scaler.fit(train_data[i:i+step])
        train_data[i:i+step] = scaler.transform(train_data[i:i+step])
    scaler.fit(train_data[i+step:])
    #We train and transform the remaining train_data
    train_data[i+step:] = scaler.transform(train_data[i+step:])
    #After that we just transform test_data without training on it so it could remain unseen
    test_data = scaler.transform(test_data.reshape(-1,1)) 
grad_norm(train_data,test_data)

# %%
# Time series visualization function
def train_test_plot(train_data,test_data,title):
    train_shape = train_data.shape[0]
    test_shape = test_data.shape[0]
    plt.figure(figsize=(15,5))
    plt.plot(np.linspace(0,train_shape,train_shape),train_data,label='Train')
    plt.plot(np.linspace(train_shape,train_shape + test_shape,test_shape),test_data,label='Test')
    plt.title(title,fontsize=15,pad=10)
    plt.legend(fontsize=12)
train_test_plot(train_data,test_data,'Normalized data')

# %% [markdown]
# #### Exponential Smoothing

# %% [markdown]
# This is a technique which can be used to reduce the complexity of the data and make it more predictable especially in the case of time series

# %%
#Function which performs the exponential smoothing
def exp_smoothing(data,smoothing_factor=0.5):
    base = 0
    for i in range(data.shape[0]):
        base = smoothing_factor*data[i] + (1 - smoothing_factor)*base
        data[i] = base
exp_smoothing(train_data, 0.5)
# There is no need in smoothing the test data, because it won't help in training

# %%
train_test_plot(train_data,test_data, 'Exponential smoothing')

# %% [markdown]
# #### Reconfiguration of Close price data

# %% [markdown]
# The common approach here is to predict every next value of time series by the certain number of its predecessors

# %%
# Function for data reconfiguration
# period is the number of preditctors or the number of predecessors we use to predict every next value in the time series 
def change_data(data, period =30): 
    predictors = []
    target = []
    for i in range(len(data) - period):
        x = data[i:i+period] # lag here is 1
        y = data[i+period]
        predictors.append(x)
        target.append(y)
    predictors = np.array(predictors).reshape(data.shape[0] - period,1,period,1)
    target = np.array(target)
    return predictors, target, period

# %%
all_data = np.concatenate([train_data,test_data])
X, y, period= change_data(all_data)
X[0] #First row of our new data
# Out:
# array([[[0.00135337],
#         [0.00067669],
#         [0.00648038],
#         [0.02291546],
#         [0.04237592],
#         [0.05335539],
#         [0.06550762],
#         [0.06637866],
#         [0.06462805],
#         [0.07374649],
#         [0.07820159],
#         [0.07824302],
#         [0.08055398],
#         [0.08254229],
#         [0.08239132],
#         [0.1021992 ],
#         [0.1127278 ],
#         [0.11809615],
#         [0.11744907],
#         [0.1142107 ],
#         [0.18962671],
#         [0.22504446],
#         [0.24847896],
#         [0.27279241],
#         [0.29785779],
#         [0.31569961],
#         [0.32857643],
#         [0.33189176],
#         [0.34572929],
#         [0.37065774]]])

# %% [markdown]
# #### Train-Test-Val seperation

# %%
new_test_size = test_size * (X.shape[0] + period)/ X.shape[0] # With this we can get the same test set
X_train, X_not_train, y_train, y_not_train = train_test_split(X, y, random_state=42, test_size = new_test_size, shuffle = False)
X_val, X_test, y_val, y_test = train_test_split(X_not_train, y_not_train, random_state=42, test_size = 0.7, shuffle = False)

# %% [markdown]
# #### Training a CNN LSTM model

# %%
#Libraries
import keras
from keras.models import Sequential
from keras.layers import Dense, LSTM, TimeDistributed, Flatten
from keras.layers.convolutional import Conv1D, MaxPooling1D
import tensorflow as tf

# %%
# Structure of the model
def make_model():
    tf.random.set_seed(42)
    np.random.seed(42)
    model = Sequential()
    #Timedistributed layer is usually used on RNN, including LSTM, to keep one-to-one relations on input and output
    model.add(TimeDistributed(Conv1D(filters=64, kernel_size=1, activation='relu'), 
                                     input_shape=(None, period, 1))) 
    model.add(TimeDistributed(MaxPooling1D(pool_size=2)))
    
    model.add(TimeDistributed(Flatten()))
    #LSTM is a recurrent neural network specialized in handling time series
    #Dropout allows not to overfit the train data and generalize much better
    model.add(LSTM(units = 200, return_sequences = True, 
                   activation = 'relu',dropout = 0.2))
    model.add(LSTM(units = 200, return_sequences = True, 
                   activation = 'relu',dropout = 0.2))
    model.add(LSTM(units = 200, return_sequences = False,
                   activation = 'relu',dropout = 0.2))
    model.add(Dense(units = 1, activation = 'linear'))
    return model
model = make_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed (TimeDistri (None, None, 30, 64)      128
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, None, 15, 64)      0
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, None, 960)         0
# _________________________________________________________________
# lstm (LSTM)                  (None, None, 200)         928800
# _________________________________________________________________
# lstm_1 (LSTM)                (None, None, 200)         320800
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 200)               320800
# _________________________________________________________________
# dense (Dense)                (None, 1)                 201
# =================================================================
# Total params: 1,570,729
# Trainable params: 1,570,729
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = make_model()
tf.random.set_seed(12345)
np.random.seed(12345)
model.compile(optimizer='adam', loss='mae')
history = model.fit(X_train, y_train, 
                    epochs = 300, validation_data=(X_val,y_val), verbose=1)
# Out:
# Epoch 1/300
# 31/31 [==============================] - 17s 183ms/step - loss: 0.4027 - val_loss: 0.2200
# Epoch 2/300
# 31/31 [==============================] - 1s 32ms/step - loss: 0.1338 - val_loss: 0.0560
# Epoch 3/300
# 31/31 [==============================] - 1s 31ms/step - loss: 0.1086 - val_loss: 0.1425
# Epoch 4/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0904 - val_loss: 0.0544
# Epoch 5/300
# 31/31 [==============================] - 1s 31ms/step - loss: 0.0792 - val_loss: 0.1206
# Epoch 6/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0852 - val_loss: 0.0594
# Epoch 7/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0622 - val_loss: 0.0439
# Epoch 8/300
# 31/31 [==============================] - 1s 29ms/step - loss: 0.0616 - val_loss: 0.0476
# Epoch 9/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0591 - val_loss: 0.0820
# Epoch 10/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0582 - val_loss: 0.0510
# Epoch 11/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0579 - val_loss: 0.0474
# Epoch 12/300
# 31/31 [==============================] - 1s 32ms/step - loss: 0.0601 - val_loss: 0.0433
# Epoch 13/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0504 - val_loss: 0.0816
# Epoch 14/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0537 - val_loss: 0.0488
# Epoch 15/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0465 - val_loss: 0.0470
# Epoch 16/300
# 31/31 [==============================] - 1s 31ms/step - loss: 0.0449 - val_loss: 0.0903
# Epoch 17/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0487 - val_loss: 0.0700
# Epoch 18/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0515 - val_loss: 0.0460
# Epoch 19/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0508 - val_loss: 0.0468
# Epoch 20/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0531 - val_loss: 0.0627
# Epoch 21/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0477 - val_loss: 0.0411
# Epoch 22/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0569 - val_loss: 0.1189
# Epoch 23/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0601 - val_loss: 0.0642
# Epoch 24/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0487 - val_loss: 0.0421
# Epoch 25/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0509 - val_loss: 0.0413
# Epoch 26/300
# 31/31 [==============================] - 1s 31ms/step - loss: 0.0467 - val_loss: 0.0809
# Epoch 27/300
# 31/31 [==============================] - 1s 31ms/step - loss: 0.0414 - val_loss: 0.0475
# Epoch 28/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0457 - val_loss: 0.0434
# Epoch 29/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0465 - val_loss: 0.0419
# Epoch 30/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0483 - val_loss: 0.0387
# Epoch 31/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0450 - val_loss: 0.0427
# Epoch 32/300
# 31/31 [==============================] - 1s 31ms/step - loss: 0.0463 - val_loss: 0.0832
# Epoch 33/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0455 - val_loss: 0.0541
# Epoch 34/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0402 - val_loss: 0.0477
# Epoch 35/300
# 31/31 [==============================] - 1s 29ms/step - loss: 0.0435 - val_loss: 0.0569
# Epoch 36/300
# 31/31 [==============================] - 1s 31ms/step - loss: 0.0449 - val_loss: 0.0581
# Epoch 37/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0459 - val_loss: 0.0720
# Epoch 38/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0423 - val_loss: 0.0470
# Epoch 39/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0442 - val_loss: 0.0552
# Epoch 40/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0421 - val_loss: 0.0662
# Epoch 41/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0433 - val_loss: 0.0495
# Epoch 42/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0392 - val_loss: 0.1051
# Epoch 43/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0496 - val_loss: 0.0431
# Epoch 44/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0569 - val_loss: 0.0895
# Epoch 45/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0441 - val_loss: 0.0626
# Epoch 46/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0417 - val_loss: 0.0798
# Epoch 47/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0419 - val_loss: 0.0403
# Epoch 48/300
# 31/31 [==============================] - 1s 31ms/step - loss: 0.0653 - val_loss: 0.0889
# Epoch 49/300
# 31/31 [==============================] - 1s 31ms/step - loss: 0.0436 - val_loss: 0.0790
# Epoch 50/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0420 - val_loss: 0.0388
# Epoch 51/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0483 - val_loss: 0.0646
# Epoch 52/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0408 - val_loss: 0.0428
# Epoch 53/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0407 - val_loss: 0.0881
# Epoch 54/300
# 31/31 [==============================] - 1s 31ms/step - loss: 0.0432 - val_loss: 0.0425
# Epoch 55/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0419 - val_loss: 0.0424
# Epoch 56/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0412 - val_loss: 0.0762
# Epoch 57/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0392 - val_loss: 0.0455
# Epoch 58/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0424 - val_loss: 0.0754
# Epoch 59/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0438 - val_loss: 0.0470
# Epoch 60/300
# 31/31 [==============================] - 1s 32ms/step - loss: 0.0389 - val_loss: 0.0779
# Epoch 61/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0394 - val_loss: 0.0517
# Epoch 62/300
# 31/31 [==============================] - 1s 31ms/step - loss: 0.0475 - val_loss: 0.0658
# Epoch 63/300
# 31/31 [==============================] - 1s 31ms/step - loss: 0.0391 - val_loss: 0.0787
# Epoch 64/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0425 - val_loss: 0.0697
# Epoch 65/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0390 - val_loss: 0.1064
# Epoch 66/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0506 - val_loss: 0.0575
# Epoch 67/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0370 - val_loss: 0.0556
# Epoch 68/300
# 31/31 [==============================] - 1s 31ms/step - loss: 0.0352 - val_loss: 0.0756
# Epoch 69/300
# 31/31 [==============================] - 1s 31ms/step - loss: 0.0462 - val_loss: 0.0665
# Epoch 70/300
# 31/31 [==============================] - 1s 29ms/step - loss: 0.0404 - val_loss: 0.0769
# Epoch 71/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0403 - val_loss: 0.0818
# Epoch 72/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0401 - val_loss: 0.0454
# Epoch 73/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0492 - val_loss: 0.0383
# Epoch 74/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0467 - val_loss: 0.0392
# Epoch 75/300
# 31/31 [==============================] - 1s 31ms/step - loss: 0.0431 - val_loss: 0.0754
# Epoch 76/300
# 31/31 [==============================] - 1s 31ms/step - loss: 0.0411 - val_loss: 0.0478
# Epoch 77/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0375 - val_loss: 0.0873
# Epoch 78/300
# 31/31 [==============================] - 1s 32ms/step - loss: 0.0391 - val_loss: 0.0579
# Epoch 79/300
# 31/31 [==============================] - 1s 32ms/step - loss: 0.0391 - val_loss: 0.0492
# Epoch 80/300
# 31/31 [==============================] - 1s 33ms/step - loss: 0.0379 - val_loss: 0.0784
# Epoch 81/300
# 31/31 [==============================] - 1s 32ms/step - loss: 0.0411 - val_loss: 0.0792
# Epoch 82/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0363 - val_loss: 0.0554
# Epoch 83/300
# 31/31 [==============================] - 1s 29ms/step - loss: 0.0364 - val_loss: 0.0429
# Epoch 84/300
# 31/31 [==============================] - 1s 29ms/step - loss: 0.0420 - val_loss: 0.0422
# Epoch 85/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0343 - val_loss: 0.0452
# Epoch 86/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0370 - val_loss: 0.0396
# Epoch 87/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0422 - val_loss: 0.0375
# Epoch 88/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0402 - val_loss: 0.1039
# Epoch 89/300
# 31/31 [==============================] - 1s 29ms/step - loss: 0.0410 - val_loss: 0.0411
# Epoch 90/300
# 31/31 [==============================] - 1s 29ms/step - loss: 0.0396 - val_loss: 0.0585
# Epoch 91/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0389 - val_loss: 0.0529
# Epoch 92/300
# 31/31 [==============================] - 1s 29ms/step - loss: 0.0382 - val_loss: 0.0811
# Epoch 93/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0374 - val_loss: 0.0506
# Epoch 94/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0410 - val_loss: 0.0580
# Epoch 95/300
# 31/31 [==============================] - 1s 29ms/step - loss: 0.0379 - val_loss: 0.0432
# Epoch 96/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0372 - val_loss: 0.0557
# Epoch 97/300
# 31/31 [==============================] - 1s 29ms/step - loss: 0.0354 - val_loss: 0.0371
# Epoch 98/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0411 - val_loss: 0.0548
# Epoch 99/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0476 - val_loss: 0.0510
# Epoch 100/300
# 31/31 [==============================] - 1s 29ms/step - loss: 0.0397 - val_loss: 0.0640
# Epoch 101/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0422 - val_loss: 0.0402
# Epoch 102/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0407 - val_loss: 0.1030
# Epoch 103/300
# 31/31 [==============================] - ETA: 0s - loss: 0.049 - 1s 30ms/step - loss: 0.0484 - val_loss: 0.0475
# Epoch 104/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0392 - val_loss: 0.0362
# Epoch 105/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0344 - val_loss: 0.0455
# Epoch 106/300
# 31/31 [==============================] - 1s 29ms/step - loss: 0.0322 - val_loss: 0.0842
# Epoch 107/300
# 31/31 [==============================] - 1s 29ms/step - loss: 0.0398 - val_loss: 0.0785
# Epoch 108/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0387 - val_loss: 0.0462
# Epoch 109/300
# 31/31 [==============================] - 1s 29ms/step - loss: 0.0355 - val_loss: 0.0414
# Epoch 110/300
# 31/31 [==============================] - 1s 29ms/step - loss: 0.0432 - val_loss: 0.0513
# Epoch 111/300
# 31/31 [==============================] - 1s 29ms/step - loss: 0.0387 - val_loss: 0.0412
# Epoch 112/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0367 - val_loss: 0.0596
# Epoch 113/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0343 - val_loss: 0.0681
# Epoch 114/300
# 31/31 [==============================] - 1s 30ms/step - loss: 0.
# 31/31 [==============================] - 1s 30ms/step - loss: 0.0347 - val_loss: 0.0546

# %% [markdown]
# #### Visualization and evaluation of predictions

# %%
#Function which allows to compare initial and predicted data
def prediction_plot(model, X, y, title = 'Predictions'):
    plt.figure(figsize = (15,7))
    plt.plot(y, c='r', label = 'Original')
    plt.plot(model.predict(X), c='g', label='Predicted')
    plt.title(title,fontsize = 15,pad = 10)
    plt.legend(fontsize=12)
    plt.xlim(y_train.shape[0]+y_test.shape[0]-100,y.shape[0]+10) 
prediction_plot(model, X, y)

# %%
#This transforms predicted values into two classes, which represent up and down movements of Close price
def up_down(x):
    x = S(x.reshape(-1))
    up_down_values=np.where((x.shift(-1) - x) > 0,1,0)
    return up_down_values
#Shows all the necessary statistics to evaluate the model 
def evaluation(model, X_test, y_test):
    from sklearn.metrics import f1_score, recall_score, accuracy_score, confusion_matrix
    test_shape = y_test.shape[0]
    labels = up_down(data['Close'].values)[period:]
    f1 = f1_score(labels[-test_shape:], up_down(model.predict(X_test)))
    recall_neg = recall_score(labels[-test_shape:], up_down(model.predict(X_test)), pos_label = 0)
    recall_pos = recall_score(labels[-test_shape:], up_down(model.predict(X_test)), pos_label = 1)
    accuracy = accuracy_score(labels[-test_shape:], up_down(model.predict(X_test)))
    confusion = confusion_matrix(labels[-test_shape:], up_down(model.predict(X_test)))
    print('F1 score:  ', f1)
    print('-----------------------------------------')
    print('Negative Recall Score:  ', recall_neg)
    print('-----------------------------------------')
    print('Positive Recall SCore :  ', recall_pos)
    print('-----------------------------------------')
    print('Accuracy SCore:  ', accuracy)
    print('-----------------------------------------')
    print('Confusion Matrix  ')
    print('    {0}'.format(confusion[0]))
    print('    {0}'.format(confusion[1]))

# %%
evaluation(model, X_test, y_test)
# Out:
# F1 score:   0.5205479452054794
# -----------------------------------------
# Negative Recall Score:   0.5714285714285714
# -----------------------------------------
# Positive Recall SCore :   0.5277777777777778
# -----------------------------------------
# Accuracy SCore:   0.5512820512820513
# -----------------------------------------
# Confusion Matrix
#     [24 18]
#     [17 19]

# %% [markdown]
# #### Predictions

# %%
def next_day_prediction():
    #Here we simply append the last prediction to the array of predictors
    new_row = np.append(X_test[-1].reshape(-1),model.predict(X_test[-1].reshape(1,1,period,1))[0,0])[1:] 
    #Now with new_row we can predict the vales of Close price for the next day
    next_day_value = model.predict(new_row.reshape(1,1,period,1))
    #We subtract today's close price from the predicted price to define the movement
    next_day_movement = np.sign(next_day_value - test_data[-1])[0]
    if next_day_movement == 1:
        print('----------------------------------------------------------')
        print()
        print('   Close price prediction for the next day is Up')
        print()
        print('----------------------------------------------------------')
    else:
        print('----------------------------------------------------------')
        print()
        print('   Close price prediction for the next day is Down')
        print()
        print('----------------------------------------------------------')
next_day_prediction()
# Out:
# ----------------------------------------------------------
#
#    Close price prediction for the next day is Down
#
# ----------------------------------------------------------

# %% [markdown]
# We could also create several other models with lags more than 1. That would allow us to make predictions for more than one day into the future, but I don't think it could give any valuable information. Even with lag = 1 we barely reach 60% accuracy so the other models won't have better performance

# %% [markdown]
# I also tried to predict movements by classification adding some other features from TA-Lib while retaining the first approach of training by periods. The problem is the accuaracy and other metrics had had roughly 50% magnitude, which is equivalent to the accuracy of coin_flipping. So I decided not to include that variant here.
